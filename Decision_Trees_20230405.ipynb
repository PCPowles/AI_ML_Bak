# %%
# Entropy
# Decision Trees
# ------------------------------------------------------------------------------------------
# Decision Trees - Concepts
# Believe it or not, given a set of training data, 
# you can actually get Python to generate a flowchart for you to make a decision.

# Name for this algorithm: It's called ID3 (Iterative Dichotomiser 3)

# Problem with decision trees is that they are very prone to overfitting.

# ------------------------------------------------------------------------------------------
# Random Forests Technique
# Now that technique of randomly resampling our data with the same model is a term called bootstrap aggregating, or bagging.
#
# "C:\Users\pcpow\OneDrive\Desktop\DataScience_Udemy_20230321\PastHires.csv"
# https://stackoverflow.com/questions/28312534/graphvizs-executables-are-not-found-python-3-4

# %%
import numpy as np
import pandas as pd
from sklearn import tree

#input_file = "C:\Users\pcpow\OneDrive\Desktop\DataScience_Udemy_20230321\PastHires.csv"
input_file = "C:/Users/pcpow/OneDrive/Desktop/DataScience_Udemy_20230321/PastHires.csv"
df = pd.read_csv(input_file, header = 0)
#df

# %%
d = {'Y': 1, 'N': 0}
df['Hired'] = df['Hired'].map(d)
df['Employed?'] = df['Employed?'].map(d)
df['Top-tier school'] = df['Top-tier school'].map(d)
df['Interned'] = df['Interned'].map(d)
d = {'BS': 0, 'MS': 1, 'PhD': 2}
df['Level of Education'] = df['Level of Education'].map(d)
#df

# %%
features = list(df.columns[:6])
features
# Out:
# ['Years Experience',
#  'Employed?',
#  'Previous employers',
#  'Level of Education',
#  'Top-tier school',
#  'Interned']

# %%
y = df["Hired"]
X = df[features]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
# p. 188
# -----------------------------------------

import six
import sys
sys.modules['sklearn.externals.six'] = six



# -----------------------------------------

from IPython.display import Image
from sklearn.externals.six import StringIO
import pydotplus

dot_data = StringIO()
tree.export_graphviz(clf, out_file=dot_data, feature_names=features)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
 from IPython.display import Image  
from sklearn.externals.six import StringIO  
import pydotplus

dot_data = StringIO()  
tree.export_graphviz(clf, out_file=dot_data,  
                         feature_names=features)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
clf
# Out:
# DecisionTreeClassifier()

# %%
import sys
# !{sys.executable} --version
# Out:
# Python 3.10.9

# %%
import nltk
import sklearn

print('The nltk version is {}.'.format(nltk.__version__))
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The nltk version is 3.7.
# The scikit-learn version is 1.2.1.

# %%
from six import StringIO

# %%
pip install six
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Ensemble learning – Using a random forest
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X, y)

# Predict employment of an employed 10-yr veteran
print (clf.predict([[10, 1, 4, 0, 0, 0]]))

# Predict employment of an unemployed 10-yr veteran
print (clf.predict([[10, 0, 4, 0, 0, 0]]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 from sklearn.ensemble import RandomForestClassifier
#       4 clf = RandomForestClassifier(n_estimators=10)
# ----> 5 clf = clf.fit(X, y)
#       7 # Predict employment of an employed 10-yr veteran
#       8 print (clf.predict([[10, 1, 4, 0, 0, 0]]))
#
# NameError: name 'X' is not defined

# %%
# pip install --upgrade scikit-learn==0.22

# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six

# %%
# %pip install pydotplus
# Out:
# ...
#   Using cached pydotplus-2.0.2.tar.gz (278 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24578 sha256=fe0f122c0b2a0736a839d3e49646c26a0823ad7eacbd826e49185905f35977ad
#   Stored in directory: c:\users\pcpow\appdata\local\pip\cache\wheels\5c\94\1f\953aa60af58ef512e5256e538ff0772c340229e5996ac51fd6
# Successfully built pydotplus
# ...
# Note: you may need to restart the kernel to use updated packages.
